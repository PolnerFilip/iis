# %%
import pandas as pd

df = pd.read_csv('../data/raw/test.csv')
df
# Out:
#     Unnamed: 0  number contract_name                                    name  \
# 0            0      24       maribor  VZAJEMNA, VARUH ZDRAVJA - BETNAVSKA C.
# 1            1      10       maribor     TELEMACH - GLAVNI TRG - STARI PERON
# 2            2       9       maribor                NKBM - TRG LEONA ŠTUKLJA
# 3            3      13       maribor     PARTIZANSKA C. - ŽELEZNIŠKA POSTAJA
# 4            4      20       maribor                  EUROPARK - POBREŠKA C.
# 5            5       4       maribor           STROSSMAYERJEVA UL. - TRŽNICA
# 6            6       1       maribor        GOSPOSVETSKA C. - TURNERJEVA UL.
# 7            7      16       maribor              KOROŠKA C. - KOROŠKI VETER
# 8            8       3       maribor        GOSPOSVETSKA C. - III. GIMNAZIJA
# 9            9      21       maribor      GORKEGA UL. - OŠ FRANCETA PREŠERNA
# 10          10       6       maribor                    POŠTA - SLOMŠKOV TRG
# ...
